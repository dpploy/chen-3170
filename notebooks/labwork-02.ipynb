# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Spring 2022 UMass Lowell; Prof. V. F. de Almeida **25Jan22**
#
# # Laboratory Work 02 (26Jan22)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <font color="red">Guidance:</font>
#
# +  <font color="red">
#     Save your work frequently to a file locally to your computer.
#    </font>
# +  <font color="red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<font color="red">, to verify your notebook runs correctly.
#    </font>
# +  <font color="red">
#     Save your file again.
#    </font>
# +  <font color="red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </font>
#
#    **lastname-firstname-labwork-xx.ipynb**
#
#    NB: Please note lowercase.

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (45 pts)](#a1) Data structure.
#  - [1.1)](#a11)(10 pts) Species data.
#  - [1.2)](#a12)(10 pts) Molar fraction sum.
#  - [1.3)](#a13)(10 pts) Reaction mechanism data.
#  - [1.4)](#a14)(15 pts) Reaction equilibrium constant stats.
# * [Assignment 2 (50 pts)](#a2) Array data inspection.
#  - [2.1)](#a21)(10 pts) Read image data array.
#  - [2.2)](#a22)(10 pts) Data type.
#  - [2.3)](#a23)(30 pts) Plot the diagonal and calculate the area.
# * [Assignment 3 (5 pts)](#a3) Unclear points
# ---

# %% [markdown]
# ## [<font color="blue">Assignment 1 (45 pts)</font>](#toa)<a id="a1"></a>

# %% [markdown]
# ### <font color="blue">[1.1)](#toa)(10 pts) Create a **single**, suitable data structure to hold all the table information below so that data is easily accessible by empirical formula. Also, the data structure must allow for an automatic sum of the mole fractions (see 1.2) below). Explain the design of your data structure.</font><a id="a11"></a>
#
# | Species | Empirical Formula | Mole Fraction | Value [%] |
# |-------------|-----------------|--------------|-------|
# |ethyl nitrite     | C2H5ONO | $x_\text{C2H5ONO}$ | 90   |
# |hydroxyethyl      | C2H5O   | $x_\text{C2H5O}$   | 1  |
# |nitrogen monoxide | NO      | $x_\text{NO}$      | 1   |
# |methyl radical    | CH3     | $x_\text{CH3}$     | 0.5  |
# |formaldehyde      | CH2O    | $x_\text{CH2O}$    | 0.5     |
# |acetaldehyde      | CH3CHO  | $x_\text{CH3CHO}$  | 1  |
# |nitroxyl          | HNO     | $x_\text{HNO}$     | 0.5      |
# |ethanol           | C2H5OH  | $x_\text{C2H5OH}$  | 1      |
# |nitrogen hydroxide| NOH     | $x_\text{NOH}$     | 0.5      |
# |nitric oxide      | N2O     | $x_\text{N2O}$     | 1      |
# |water             | H2O     | $x_\text{H2O}$     | 1   |
# |formamide         | CH3NO   | $x_\text{CH3NO}$   | 1      |
# |formaldoxime      | CH2=NOH | $x_\text{CH2=NOH}$ | 0.5   |
# |hydrogen cyanide  | HCN     | $x_\text{HCN}$     | 0.5      |

# %%
'''Data structure'''

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ### <font color="blue">[1.2)](#toa)(10 pts) Using only the contents of the course Notebooks 1 to 3, use your data structure from 1.1) to sum the molar fractions and present the result. Your code must not have more than 2 lines not counting print and import statements. </font><a id="a12"></a>

# %%
'''Molar fraction sum from your data structure'''

# %% [markdown]
# ### <font color="blue">[1.3)](#toa)(10 pts) Create a **single**, suitable data structure to hold all the information below so that data is easily accessible by reaction row index. Explain the design of your data structure.</span><a id="a13"></a>
#
#  index | Reaction mechanism     |         $K_x$        |
# -------|------------------------|----------------------|
# 0      | C2H5ONO      <=> C2H5O   + NO   | 5.02e+00        |
# 1      | C2H5O        <=> CH3     + CH2O | 3.23e+00        |
# 2      | C2H5O + NO   <=> CH3CHO  + HNO  | 2.12e+00        |
# 3      | C2H5O + HNO  <=> C2H5OH  + NO   | 3.65e+00        |
# 4      | 2 NOH        <=> N2O     + H2O  | 1.45e-01   |
# 5      | CH3 + NO     <=> CH3NO          | 1.67e+00     |
# 6      | CH3NO        <=> CH2=NOH        | 1.09e-00   |
# 7      | CH2=NOH      <=> HCN     + H2O  | 1.14e-01   |

# %%
'''Data structure'''

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ### <font color="blue">[1.4)](#toa)(15 pts) Using only the contents of the course Notebooks 1 to 3, use your data structure from 1.3) to compute the average equilibrium constant and the standard deviation. Your code must not have more than 2 lines not counting print statements. Explain your work.</font><a id="a14"></a>

# %%
'''Code for molar equilibrium constant statistics'''
# Out:
# K_x average =  2.130e+00
# K_x std     =  1.627e+00

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 2 (50 pts)</font>](#toa)<a id="a2"></a>

# %% [markdown]
# ### <font color="blue">[2.1)](#toa)(10 pts) Import this [image (cermet scanning electron micrograph)](https://raw.githubusercontent.com/dpploy/chen-3170/master/notebooks/images/cermet.png) as an array and produce the plot below as close as possible.</span><a id="a21"></a>

# %%
'''Code'''

# %% [markdown]
# ### <font color="blue">[2.2)](#toa)(10 pts) What is the data type? Explain what it means and compare to 2.2).</font><a id="a22"></a>

# %%
'''Data Type Code'''

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ### <font color="blue">[2.3)](#toa)(30 pts) Plot the diagonal and its mean, as below, and calculate the area using only the course Notebooks 1 to 4 contents. Explain your work.</span><a id="a23"></a>

# %%
'''Plot and Area Code'''

# %%
# Out:
# Area = 219.82

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 3 (5 pts)</font>](#toa)<a id="a3"></a>

# %% [markdown]
# ### <font color="blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</font>

# %% [markdown]
# **Description and troubleshooting:**
