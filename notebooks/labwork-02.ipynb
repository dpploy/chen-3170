# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Fall 2021 UMass Lowell; Prof. V. F. de Almeida **15Sep21**
#
# # Laboratory Work 02 (16Sep21)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#
# +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#    </span>
# +  <span style="color:red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<span style="color:red">, to verify your notebook runs correctly.
#    </span>
# +  <span style="color:red">
#     Save your file again.
#    </span>
# +  <span style="color:red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </span>
#
#    **lastname-firstname-labwork-xx.ipynb**

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (35 pts)](#a1) Data structure.
#  - [1.1)](#a11)(5 pts) Species data.
#  - [1.2)](#a12)(5 pts) Molar fraction sum.
#  - [1.3)](#a13)(10 pts) Reaction mechanism data.
#  - [1.4)](#a14)(15 pts) Reaction equilibrium constant stats.
# * [Assignment 2 (40 pts)](#a2) Array data inspection.
#  - [2.1)](#a21)(5 pts) Read image data array.
#  - [2.2)](#a22)(5 pts) Data type.
#  - [2.3)](#a23)(15 pts) Calculate the diameter
#  - [2.4)](#a24)(15 pts) Calculate the hot spot area
# * [Assignment 3 (20 pts)](#a3) Array data inspection.
#  - [3.1)](#a31)(5 pts) Read image data array.
#  - [3.2)](#a32)(5 pts) Data type.
#  - [3.3)](#a33)(10 pts) Plot the diagonal and calculate the area.
# * [Assignment 4 (5 pts)](#a4) Unclear points
# ---

# %% [markdown]
# ## <span style="color:blue">[Assignment 1 (35 pts)](#toa)</span><a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(5 pts) Create a single, suitable data structure to hold all this information (see table below) so that data is easily accessible by empirical formula. Explain the design of your data structure.</span><a id="a11"></a>
#
# | Species | Empirical Formula | Mole Fraction | Value [%] |
# |-------------|-----------------|--------------|-------|
# |ethyl nitrite     | C2H5ONO | $x_\text{C2H5ONO}$ |  0.9   |
# |hydroxyethyl      | C2H5O   | $x_\text{C2H5O}$   | 1  |
# |nitrogen monoxide | NO      | $x_\text{NO}$      | 1   |
# |methyl radical    | CH3     | $x_\text{CH3}$     | 0.5  |
# |formaldehyde      | CH2O    | $x_\text{CH2O}$    | 0.5     |
# |acetaldehyde      | CH3CHO  | $x_\text{CH3CHO}$  | 1  |
# |nitroxyl          | HNO     | $x_\text{HNO}$     | 0.5      |
# |ethanol           | C2H5OH  | $x_\text{C2H5OH}$  | 1      |
# |nitrogen hydroxide| NOH     | $x_\text{NOH}$     | 0.5      |
# |nitric oxide      | N2O     | $x_\text{N2O}$     | 1      |
# |water             | H2O     | $x_\text{H2O}$     | 1   |
# |formamide         | CH3NO   | $x_\text{CH3NO}$   | 1      |
# |formaldoxime      | CH2=NOH | $x_\text{CH2=NOH}$ | 0.5   |
# |hydrogen cyanide  | HCN     | $x_\text{HCN}$     | 0.5      |

# %%
'''Data structure'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(10 pts) Using only the contents of the course Notebooks 1 to 4, use your data structure to sum the molar fractions and present the result. Your code must not have more than 1 line not counting print and import statements. </span><a id="a12"></a>

# %%
'''Molar fraction sum from your data structure'''
# Out:
# 1.0

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(10 pts) Create a single, suitable data structure to hold all this information (see table below) so that data is easily accessible by reaction row index in the table below. Explain the design of your data structure.</span><a id="a13"></a>
#
#  Reaction mechanism            |         $K_x$        |
# --------------------------------|----------------------|
# C2H5ONO      <=> C2H5O   + NO   | 5.02e+00        |
# C2H5O        <=> CH3     + CH2O | 3.23e+00        |
# C2H5O + NO   <=> CH3CHO  + HNO  | 2.12e+00        |
# C2H5O + HNO  <=> C2H5OH  + NO   | 3.65e+00        |
# 2 NOH        <=> N2O     + H2O  | 1.45e-01   |
# CH3 + NO     <=> CH3NO          | 1.67e+00     |
# CH3NO        <=> CH2=NOH        | 1.09e-00   |
# CH2=NOH      <=> HCN     + H2O  | 1.14e-01   |

# %%
'''Data structure'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(15 pts) Using only the contents of the course Notebooks 1 to 4, use your data structure to compute the average equilibrium constant and the standard deviation. Your code must not have more than 2 lines not counting print statements. Explain your work.</span><a id="a14"></a>

# %%
'''Code for molar equilibrium constant statistics'''
# Out:
# K_x average =  2.130e+00
# K_x std     =  1.627e+00

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (40 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(5 pts) Import this [image (fluid flow and heat transfer simulation on a symmetric sector of a nuclear reactor core cross section)](https://raw.githubusercontent.com/dpploy/chen-3170/master/notebooks/images/cp21.8-T.png) as an array and produce the plot below as close as possible.</span><a id="a21"></a>

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(5 pts) What is the data type? Explain what it means.</span><a id="a22"></a>

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[2.3)](#toa)(15 pts) The circles in the image represent fuel pins and flow channels cross sections. Calculate the diameter in mm as best as possible and explain your work visually.</span><a id="a23"></a>

# %%
'''Diameter Code'''
# Out:
# diameter = 16.92 [mm]

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[2.4)](#toa)(15 pts) Calculate the area of the hot spot in the cross section and show this area as below. Also explain your work.</span><a id="a24"></a>

# %%
'''Area Code'''

# %%
# Out:
# Area of hot spot = 21.33 [cm^2]

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 3 (20 pts)](#toa)</span><a id="a3"></a>

# %% [markdown]
# ### <span style="color:blue">[3.1)](#toa)(5 pts) Import this [image (cermet scanning electron micrograph)](https://raw.githubusercontent.com/dpploy/chen-3170/master/notebooks/images/cermet.png) as an array and produce the plot below as close as possible.</span><a id="a31"></a>

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[3.2)](#toa)(5 pts) What is the data type? Explain what it means and compare to 2.2).</span><a id="a32"></a>

# %%
'''Data Type Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[3.3)](#toa)(10 pts) Plot the diagonal and its mean, as below, and calculate the area under the curve using only the course Notebooks 1 to 4 contents. Explain your work.</span><a id="a33"></a>

# %%
'''Plot and Area Code'''

# %%
# Out:
# Area = 219.82

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 4 (5 pts)](#toa)</span><a id="a4"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>
