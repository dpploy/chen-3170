# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Fall 2018 UMass Lowell; Prof. V. F. de Almeida **20Sep2018**
#
# # Laboratory 03 Work 20Sep2018 Session 801/802

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |                             |  Points |
# | -----------------------     | ------- |
# | Precision of the answer     |   80%   |
# | Answer Markdown readability |   10%   |
# | Code readability            |   10%   |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#  +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#     </span>
#  +  <span style="color:red">
#     During your work and before submitting the final version do: `Kernel` -> `Restart & Run All`, to verify your notebook runs correctly.
#     </span>
#  +  <span style="color:red">
#     Save your file again.
#     </span>

# %% [markdown]
# ## <span style="color:blue">Assignment 1 (25 pts): For each item below respond in a separate notebook cell.</span>
# * <span style="color:blue">Import the image: https://raw.githubusercontent.com/dpploy/chen-3170/master/images/cermet.png as a matrix.</span>
# * <span style="color:blue">What is the data type?</span>
# * <span style="color:blue">Show the matrix as an image with title: "Cermet", and axes labels: "x pixel" and "y pixel"; use a gray colormap in `imshow()`. </span>
# * <span style="color:blue">Print the shape of array.</span>
# * <span style="color:blue">Print the maximum, mininum, mean, and variance values of the matrix.</span>
# * <span style="color:blue">Coarsen the data by a factor of 20 and visualize the result.</span>

# %%
# Out:
# mtrx type = <class 'numpy.ndarray'>

# %%
# Out:
# mtrx shape = (500, 500)

# %%
# Out:
# mtrx max.  = 0.8901961
# mtrx min.  = 0.0627451
# mtrx mean  = 0.47066498
# mtrx var.  = 0.050064627

# %% [markdown]
# ## <span style="color:blue">Assignment 2 (25 pts): For each item below respond in a separate notebook cell.</span>
# * <span style="color:blue">Produce a plot of the diagonal of the original matrix in Assignment 1. Give the plot a meaningful title and a meaningful label for the axes; *i.e.* explain what the plot represents.</span>
# * <span style="color:blue">Repeat the previous item with data coarsened by a factor of 5.</span>

# %% [markdown]
# ## <span style="color:blue">Assignment 3 (25 pts): For each item below respond in a separate notebook cell.</span>
# * <span style="color:blue">Draw a diagonal white line on the image of the original matrix in Assignment 1; but preserve the original data.</span>
# * <span style="color:blue">Transpose the matrix with the white diagonal line and visualize the result. Does the diagonal line changes under transposition?</span>

# %% [markdown]
# The diagonal does not change under transposition but the image is rotated clockwise 90 degrees and flipped right to left.

# %% [markdown]
# ## <span style="color:blue">Assignment 4 (25 pts): For each item below respond in a separate notebook cell.</span>
# * <span style="color:blue">Concatenate two original matrices from Assignment 1 in the horizontal direction and visualize the resulting matrix; title the plot *Horizontal Concatenation*.</span>
# * <span style="color:blue">Concatenate two original matrices from Assignment 1 in the vertical direction and visualize the resulting matrix; title the plot *Vertical Concatenation*.</span>
