# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Fall 2021 UMass Lowell; Prof. V. F. de Almeida **27Oct21**
#
# # Laboratory Work 05 (28Oct21)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#
# +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#    </span>
# +  <span style="color:red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<span style="color:red">, to verify your notebook runs correctly.
#    </span>
# +  <span style="color:red">
#     Save your file again.
#    </span>
# +  <span style="color:red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </span>
#
#    **lastname-firstname-labwork-xx.ipynb**

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (30 pts)](#a1) Acetyldehyde pyrolysis
#  - [1.1)](#a11)(10 pts) Reaction mechanism.
#  - [1.2)](#a12)(10 pts) Stoichiometric analysis.
#  - [1.3)](#a13)(10 pts) Reaction rate calculation.
# * [Assignment 2 (35 pts)](#a2) Propane pyrolysis.
#  - [2.1)](#a21)(10 pts) Reaction mechanism.
#  - [2.2)](#a22)(10 pts) Stoichiometric analysis.
#  - [2.3)](#a23)(15 pts) Reaction rate calculation.
# * [Assignment 3 (30 pts)](#a3) COVID-19 US death data.
#  - [3.1)](#a31)(10 pts) Import and plot data.
#  - [3.2)](#a32)(10 pts) LLSQ method with polynomial basis functions.
#  - [3.3)](#a33)(10 pts) Error analysis.
# * [Assignment 4 (5 pts)](#a4) Unclear points.
# ---

# %% [markdown]
# ## <span style="color:blue">[Assignment 1 (30 pts)](#toa)</span><a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(10 pts) Import the following reaction mechanism for acetaldehyde pyrolysis from the course repository: `data/acetaldehyde-pyrolysis-rxn.txt` and display the reactions.</span><a id="a11"></a>

# %%
'''1.1) Read reaction mechanism'''
# Out:
# r0 :  I2         <=> 2 I
# r1 :  I + CH3CHO <=> HI + CH3CO
# r2 :  CH3CO      <=> CH3 + CO
# r3 :  CH3 + I2   <=> CH3I + I
# r4 :  CH3 + HI   <=> CH4 + I
# n_reactions = 5

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(10 pts) Print and plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is mass conservation satisfied? Explain.</span><a id="a12"></a>

# %%
'''1.2) Stoichimetric matrix data'''
# Out:
# matrix shape = (5, 9)

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(10 pts) Given the species production rate density vector [mol/(s cc)] below, </span>
# <br>
# <span style="color:blue">
# $\gvec = \begin{pmatrix}
# -2.9771 \\ -3.2678 \\ 1.8517 \\ 1.6841 \\ 2.7091 \\ 1.4161 \\ 0.5587 \\ -4.3282 \\ 1.0427
#  \end{pmatrix}
# $
# </span>
# in this order:
# CH3, CH3CHO, CH3CO, CH3I, CH4, CO, HI, I, I2
#
# ### <span style="color:blue"> compute and plot the reaction rate density vector (state units), explain step-by-step the solution of the problem, and explain in what sense is the reaction rate density vector a solution of the problem. Is the solution unique? Justify your answer? Explain the meaning of the sign of the reaction rates.
# </span><a id="a13"></a>

# %%
'''1.3) Code to calculate reaction rates'''
# Out:
# r [unit?] =  [-2.7268  3.2678  1.4161  1.6841  2.7091]

# %%
'''1.3) Plot of reaction rates'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (35 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(10 pts) Import the following reaction mechanism for propane pyrolysis from the course repository: `data/propane-rxn.txt` and display the reactions: </span><a id="a21"></a>

# %%
'''1.1) Read reaction mechanism'''
# Out:
# r0 :  C3H8         <-> CH3* + C2H5*
# r1 :  C3H8 + H*    <-> H2 + C3H7*
# r2 :  C3H7*        <-> C3H6 + H*
# r3 :  C2H5*        <-> C2H4 + H*
# r4 :  C3H7*        <-> C2H4 + CH3*
# r5 :  C2H5* + C3H8 <-> C2H6 + C3H7*
# r6 :  CH3* + C3H8  <-> CH4 + C3H7*
# r7 :  CH3* + C3H7* <-> C3H6 + CH4
# n_reactions = 8

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(10 pts) Print and plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is mass conservation satisfied? Explain.</span><a id="a22"></a>

# %%
'''2.2) Stoichimetric matrix data'''
# Out:
# matrix shape = (8, 10)

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[2.3)](#toa)(15 pts) Given the species production rate density vector [mol/(s cc)] below, </span><a id="a22"></a>
# <br>
# <span style="color:blue">
# $\gvec = \begin{pmatrix}
#  1.6795  \\ 0.7847  \\ 1.4312 \\ -5.0052 \\ 11.8774 \\ -10.7675 \\ 3.9742 \\ -0.0788 \\ -6.0451 \\  4.1195
#  \end{pmatrix}
# $
# </span>
# in this order: C2H4, C2H5*, C2H6, C3H6, C3H7*, C3H8, CH3*, CH4, H*, H2
#
# ### <span style="color:blue"> compute and plot the reaction rate density vector (state units), explain step-by-step the solution of the problem, and explain in what sense is the reaction rate density vector a solution of the problem. Is the solution unique? Justify your answer? Explain the meaning of the sign of the reaction rates.
# </span><a id="a23"></a>

# %%
'''2.3) Code to calculate reaction rates'''
# Out:
# r [unit?] =  [ 2.819   4.1195 -2.5287  0.6031  1.0764  1.4312  2.3978 -2.4766]

# %%
'''2.3) Plot of reaction rates'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 3 (30 pts)](#toa)</span><a id="a3"></a>

# %% [markdown]
# ### <span style="color:blue">[3.1)](#toa)(10 pts) Import the COVID-19 US death data below (you will need internet connection) and reproduce the plot and printout below; dates spaced by 15 days.</span><a id="a31"></a>

# %%
'''3.1) Get data per state/territory in US'''

from chen_3170.help import get_covid_19_us_data

case_type = 'deaths'
(state_names, populations, dates, cases) = get_covid_19_us_data(type=case_type)

# %%
'''3.1) Sum cases'''
import numpy as np
population = np.sum(populations)
us_cases = np.sum(cases,axis=1)
# select data with non-zero cases only
(nz_cases_ids,) = np.where(us_cases>0)
us_cases = us_cases[nz_cases_ids]
us_dates = dates[nz_cases_ids]

# %%
'''3.1) Select data up until a given date'''

#date = None # get all the data available
date = '10/27/21' # set end date wanted
if date is not None:
    assert isinstance(date, str)
    (id,) = np.where(us_dates==date)
    assert id.size == 1
    us_dates = np.copy(us_dates[:id[0]+1])
    us_cases = np.copy(us_cases[:id[0]+1])

# %%
'''3.1) Plot data'''
# Out:
# Last 5 days # of cumulative cases = [735791. 735932. 737333. 739081. 741222.]
# Last 5 days # of added cases = [141.0, 1401.0, 1748.0, 2141.0]

# %% [markdown]
# ### <span style="color:blue">[3.2)](#toa)(10 pts) Approximate the data using the linear least-squares method with polynomial basis functions using your algorithms. Find a polynomial degree that fits the data with mean local relative error less than 12%. Make a plot as below. Explain the method you used as best as you can.
# </span><a id="a32"></a>

# %%
'''3.2) Build linear system'''

# %%
'''3.2) Plot the LS Fourier fit and all modes'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[3.3)](#toa)(10 pts) Analyze the local relative error and explain. How would you improve this method to fit the data with a much lower error?</span><a id="a33"></a>

# %%
'''3.3) Local relative errors'''
# Out:
# Discard dates with small number of cases: > 1000
# Local Relative Error:
# mean [%] = 11.94
# std  [%] = 71.92
# max, min [%] = 1030.82, 0.00

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 4 (5 pts)](#toa)</span><a id="a4"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>
