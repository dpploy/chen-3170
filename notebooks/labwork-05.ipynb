# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Spring 2023 UMass Lowell; Prof. V. F. de Almeida **15Mar23**
#
# # Laboratory Work 05 (17Mar23)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\onevec}{\boldsymbol{\mathsf{1}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
#   \DeclareMathOperator{\sym}{sym}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <font color="red">Guidance:</font>
#
# +  <font color="red">
#     Save your work frequently to a file locally to your computer.
#    </font>
# +  <font color="red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<font color="red">, to verify your notebook runs correctly.
#    </font>
# +  <font color="red">
#     Save your file again.
#    </font>
# +  <font color="red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </font>
#
#    **lastname-firstname-labwork-xx.ipynb**
#
#    NB: Please note lowercase.

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (5 pts)](#a1) Solver function.
#  - [1.1)](#a11)(5 pts) Function and testing.
# * [Assignment 2 (30 pts)](#a2) Acetaldehyde pyrolysis
#  - [2.1)](#a21)(6 pts) Import reaction mechanism.
#  - [2.2)](#a22)(6 pts) Data organization.
#  - [2.3)](#a23)(6 pts) Rank and mass conservation.
#  - [2.4)](#a24)(6 pts) Compute reaction rate case 1.
#  - [2.5)](#a25)(6 pts) Compute reaction rate case 2.
# * [Assignment 3 (30 pts)](#a3) Nitric acid radiolysis.
#  - [3.1)](#a31)(6 pts) Import reaction mechanism.
#  - [3.2)](#a32)(6 pts) Data organization.
#  - [3.3)](#a33)(6 pts) Rank and mass conservation.
#  - [3.4)](#a34)(6 pts) Compute reaction rate case 1.
#  - [3.5)](#a35)(6 pts) Compute reaction rate case 2.
# * [Assignment 4 (30 pts)](#a4) LLSQ with Fourier basis.
#  - [4.1)](#a41)(3 pts) Import data.
#  - [4.2)](#a42)(9 pts) Five pairs of cosine/sine
#  - [4.3)](#a43)(9 pts) Ten pairs of cosine/sine.
#  - [4.4)](#a44)(9 pts) Fifteen pairs of cosine/sine.
# * [Assignment 5 (5 pts)](#a5) Unclear points.
# ---

# %% [markdown]
# ## [<font color="blue">Assignment 1 (5 pts)</font>](#toa)<a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(5 pts) Code your own Python function to solve $\Amtrx\,\xvec=\bvec$. Add a documentation string section to be used with the Python function `help()` function. Demonstrate the function is correctly implemented, and explain your testing approach.</span><a id="a11"></a>

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## [<font color="blue">Assignment 2 (30 pts)</font>](#toa)<a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(6 pts) Import the following reaction mechanism for acetaldehyde pyrolysis from the course repository `data/acetaldehyde-pyrolysis-rxn.txt`, keep the order of the reactions the same, and display the reactions.</span><a id="a21"></a>

# %%
'''Code'''
# Out:
# r0 :  I2         <=> 2 I
# r1 :  I + CH3CHO <=> HI + CH3CO
# r2 :  CH3CO      <=> CH3 + CO
# r3 :  CH3 + I2   <=> CH3I + I
# r4 :  CH3 + HI   <=> CH4 + I
# n_reactions = 5

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(6 pts) Make an organized output of the species and stoichiometric data.</span><a id="a22"></a>

# %%
'''Code'''
# Out:
# matrix shape = (5, 9)

# %% [markdown]
# ### <span style="color:blue">[2.3)](#toa)(6 pts)  Compute the rank of the stoichiometric matrix using your own algorithm. Is the matrix full rank? Is mass conserved? Explain.</span><a id="a23"></a>

# %%
'''Code'''
# Out:
# rank =  5

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[2.4)](#toa)(6 pts) Given the species production rate density vector [mol/(s cc)] below, </span><a id="a24"></a>
# <br>
# <span style="color:blue">
# $\gvec = \begin{pmatrix}
#  -2.77215 \\
#   1.35094 \\
#   0.69238 \\
#  -2.37983 \\
#  -2.26631 \\
#  -2.47606 \\
#   0.12406  \\
#  -1.48609 \\
#  -0.55333
#  \end{pmatrix}
# $
# </span>
# <br><br>
#
# <span style="color:blue">
#    in the order:   I, CH3CO, HI, CO, CH3I, CH3CHO, I2, CH4, CH3,
#  </span>
#
# ### <span style="color:blue">compute the reaction rates vector and make a plot. Use your own algorithms and explain your work, that is, what is the meaning of your computed reaction rate vector? What problem are you solving to obtain the reaction rate vector from the given production rate vector? Do the reaction rate equations have a solution? If so, is it unique? Why or why not?</span><a id="a24"></a>

# %%
'''Code'''
# Out:
# reaction rates r_vec= [0.17501, 0.89586, -1.72021, -1.20689, -0.56551]

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[2.5)](#toa)(6 pts) Given the species production rate density vector [mol/(s cc)] below, </span><a id="a25"></a>
# <br>
# <span style="color:blue">
# $\gvec = \begin{pmatrix}
#  0.78133  \\ 0.1814 \\ -1.70025 \\ 1.05937 \\ -0.32185 \\ 1.51885 \\ 0.14045 \\ -0.02107 \\ -0.58938
#  \end{pmatrix}
# $
# </span>
# <br><br>
#
# <span style="color:blue">
#    in the order:   CH3, CH3CHO, CH3CO, CH3I, CH4, CO, HI, I, I2
#  </span>
#
# ### <span style="color:blue">compute the reaction rates vector and make a plot. Use your own algorithms and explain your work, that is, what is the meaning of your computed reaction rate vector? What problem are you solving to obtain the reaction rate vector from the given production rate vector? Do the reaction rate equations have a solution? If so, is it unique? Why or why not?</span>

# %%
'''Code'''
# Out:
# r_vec [mols/(s cc)]=  [-0.46999 -0.1814   1.51885  1.05937 -0.32185]

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## [<font color="blue">Assignment 3 (30 pts)</font>](#toa)<a id="a3"></a>

# %% [markdown]
# ### <span style="color:blue">[3.1)](#toa)(6 pts) Write a code to import the following reaction mechanism for nitric acid radiolysis from the course repository `data/hno3-rad-short-rxn.txt`, keep the order of reactions the same, and display the reactions.</span><a id="a31"></a>

# %%
'''Code'''
# Out:
# r0 :  *NO3^2- + H^+ <-> *NO2 + OH^-
# r1 :  e^- + NO3^- <-> *NO3^2-
# r2 :  *NO3^2- + H^+ <-> HNO3 + e^-
# r3 :  *NO3^2- + *OH <-> NO3^- + OH^-
# r4 :  *NO3^2- + O2 <-> NO3^- + O2^-
# r5 :  N2O4 + H2O <-> NO3^- + NO2^- + 2 H^+
# r6 :  *NO2 + *OH <-> NO3^- + H^+
# r7 :  *NO2 + H* <-> HNO2
# r8 :  *NO2 + HO2* <-> O2NO2H
# r9 :  O2NO2H <-> O2NO2^- + H^+
# r10 :  O2NO2^- + H^+ <-> O2NO2H
# r11 :  O2NO2^- + H^+ + 2 e^- <-> OH^- + NO3^-
# r12 :  O2NO2H + e^- <-> *OH + NO3^-
# r13 :  NO2^- + *OH <-> *NO2 + OH^-
# r14 :  NO2^- + e^- <-> NO2^2-
# r15 :  NO2^- + H2O + e^- <-> NO + 2 OH^-
# r16 :  ONO2H + e^- <-> *NO2 + OH^-
# r17 :  NO + e^- <-> NO^-
# r18 :  NO + H* <-> NO^- + H^+
# r19 :  NO + *OH <-> NO2^- + H^+
# r20 :  NO + O2^- <-> ONO2^-
# r21 :  NO + HO2* <-> ONO2H
# r22 :  ONO2^- + e^- + H2O <-> *NO2 + 2 OH^-
# r23 :  *NO2 + NO + H2O <-> 2 HNO2
# n_reactions = 24

# %% [markdown]
# ### <span style="color:blue">[3.2)](#toa)(6 pts) Make an organized output of the species and stoichiometric data.</span><a id="a32"></a>

# %%
'''Code'''
# Out:
# matrix shape = (24, 23)

# %% [markdown]
# ### <span style="color:blue">[3.3)](#toa)(6 pts)  Compute the rank of the stoichiometric matrix using your own algorithm. Is the matrix full rank? Is mass conserved for the first 3 reactions and the last 3 reactions? Explain.</span><a id="a33"></a>

# %%
'''Code'''
# Out:
# rank =  19

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[3.4)](#toa)(6 pts) Given the species production rate density vector [mol/(s cc)] below, </span><a id="a34"></a>
# <br>
# <span style="color:blue">
# $\gvec$ =
#   [ 0.23304 , 1.23866 , 2.88767 , 1.33591 , -2.19033 , 2.37728 , 1.38655 , -0.16364 , 2.82705 , 2.55334 , -1.59161 , 3.32964   ,-0.38149 , -1.95735 , 1.06984 , 2.33603 , -0.09187 , -0.70079 , 1.30244 , -1.63818 , -1.22492 , 3.00651 , -1.389 ]
# </span>
# <br><br>
#
# <span style="color:blue">
#    in the order:   [*NO2, *NO3^2-, *OH, H*, H2O, HNO2, HNO3, HO2*, H^+, N2O4, NO, NO2^-, NO2^2-, NO3^-, NO^-, O2, O2NO2H, O2NO2^-, O2^-, OH^-, ONO2H, ONO2^-, e^-]
#  </span>
#
# ### <span style="color:blue">compute the reaction rates vector and make a plot. Use your own algorithms and explain your work, that is, what is the meaning of your computed reaction rate vector? What problem are you solving to obtain the reaction rate vector from the given production rate vector? Do the reaction rate equations have a solution? If so, is it unique? Why or why not?</span>

# %%
'''Code'''
# Out:
# r_vec = [0.38107, -1.39771, 0.45992, -1.41144, -1.88036, -0.76501, -1.79251, -4.38121, -0.98825, -0.82669, 0.82669, -0.07099, 1.91147, -3.18997, -0.33921, 5.31067, 3.56374, -1.9782, 2.84993, 5.45019, -3.19535, 1.41219, -5.54808, 3.02985]

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[3.5)](#toa)(6 pts) Given the species production rate density vector [mol/(s cc)] below, </span><a id="a35"></a>
# <br>
# <span style="color:blue">
# $\gvec$ =
#   0.97228, -4.66817, -1.19803,  0.38276, -0.51644,  0.99474, -0.19412,  2.75167, -0.68798, -2.06599,  5.69336, 2.63653, 1.73704,  2.26838, -2.22961,  1.27009,  3.05712, -1.99614,  0.77853,  0.18902, -4.26231,  0.12287,  3.40469  ]
# </span>
# <br><br>
#
# <span style="color:blue">
#    in the order:   [*NO2, *NO3^2-, *OH, H*, H2O, HNO2, HNO3, HO2*, H^+, N2O4, NO, NO2^-, NO2^2-, NO3^-, NO^-, O2, O2NO2H, O2NO2^-, O2^-, OH^-, ONO2H, ONO2^-, e^-]
#  </span>
#
# ### <span style="color:blue">compute the reaction rates vector and make a plot. Use your own algorithms and explain your work, that is, what is the meaning of your computed reaction rate vector? What problem are you solving to obtain the reaction rate vector from the given production rate vector? Do the reaction rate equations have a solution? If so, is it unique? Why or why not?</span>

# %%
'''Code'''
# Out:
# r_vec = [2.51149, -1.99949, -0.19412, 1.62139, -1.27009, 2.06599, -0.8901, 0.24206, -0.19732, -1.12574, 1.12574, -0.25533, -1.00297, -1.5447, 1.73704, 0.2456, 1.70796, -1.60479, -0.62482, 1.00848, -2.04862, -2.55435, -2.17149, 0.37634]

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## [<font color="blue">Assignment 4 (30 pts)</font>](#toa)<a id="a4"></a>

# %% [markdown]
# ### <span style="color:blue">[4.1)](#toa)(3 pts) Write a Python function for reading the data from the repository file `data/fourier.dat` and make the following plot.</span><a id="a41"></a>

# %%
'''Code'''
# Out:
# m =  26
# x [xau] = [-2.   -1.   -1.14 -0.29  0.    0.57  1.    1.43  2.    2.29  3.    3.14
#   4.    5.    4.86  5.71  6.    6.5   6.57  7.    7.43  7.5   8.29  9.
#   9.14 10.  ]
# y [yau] = [ -9.37  10.    10.83 -13.88 -18.    -1.83  14.    14.5    0.    -1.38
#   28.    35.64  37.88 -23.   -17.52 -14.63  -1.   -15.    -1.73  12.
#    5.97   2.    22.78   1.    -6.41  -9.37]

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[4.2)](#toa)(9 pts) Fit the data with the linear least-squares fit method using Fourier basis functions. Use 5 pairs of sines and cosines and create the plots/results below. Explain the procedure and results.</span><a id="a42"></a>

# %%
'''Code'''
# Out:
# x_vec = [  4.685  -1.709  10.136 -10.321 -10.848   5.276   7.899 -12.453   2.471
#   -0.795  -2.962]

# %%
'''Code'''

# %%
'''Code'''
# Out:
# Local Relative Error (discarding y values < 0.1):
# mean [%] = 21.25
# std  [%] = 178.05
# max, min [%] = 754.63, -178.17

# %% [markdown]
# *discarding $|y|$ values < 0.1*

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[4.3)](#toa)(9 pts) Fit the data with the linear least-squares fit method using Fourier basis functions. Use 10 pairs of sines and cosines and create the plots/results below. Explain the procedure and results (compare against 4.2).</span><a id="a43"></a>

# %%
'''Code'''
# Out:
# x_vec = [  4.995  -1.624   9.339 -10.278 -11.465   4.794   7.555 -14.394   1.139
#   -2.097   0.597   0.421   3.29    6.218   0.639   0.823  -5.083  -2.538
#   -0.87   -0.107   1.576]

# %%
'''Code'''

# %%
'''Code'''
# Out:
# Local Relative Error (discarding y values < 0.1):
# mean [%] = 21.79
# std  [%] = 94.20
# max, min [%] = 390.26, -74.18

# %% [markdown]
# *discarding $|y|$ values < 0.1*

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[4.4)](#toa)(9 pts) Fit the data with the linear least-squares fit method using Fourier basis functions. Use 15 pairs of sines and cosines and create the plots/results below. Explain the procedure and results (compare against 4.3).</span><a id="a44"></a>

# %%
'''Code'''
# Out:
# x_vec = [ 1.591 -0.42   5.684 -5.112 -2.257  0.36   4.546 -7.626  0.341 -4.391
#   1.092  1.878  4.286  7.783 -3.427 -4.608  1.763 -0.957 -1.751  3.441
#   2.857 -2.624  2.96   0.911 -2.538  2.782 -1.943 -8.819  1.635  2.123
#   2.123]

# %%
'''Code'''

# %%
'''Code'''
# Out:
# Local Relative Error (discarding y values < 0.1):
# mean [%] = 17.08
# std  [%] = 89.43
# max, min [%] = 450.00, -45.00

# %% [markdown]
# *discarding $|y|$ values < 0.1*

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ## [<font color="blue">Assignment 5 (5 pts)</font>](#toa)<a id="a5"></a>

# %% [markdown]
# ### <font color="blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</font>

# %% [markdown]
# **Description and troubleshooting:**
