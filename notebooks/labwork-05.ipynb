# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Spring 2022 UMass Lowell; Prof. V. F. de Almeida **14Mar22**
#
# # Laboratory Work 05 (14Mar22)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\zerovec}{\boldsymbol{0}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <font color="red">Guidance:</font>
#
# +  <font color="red">
#     Save your work frequently to a file locally to your computer.
#    </font>
# +  <font color="red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<font color="red">, to verify your notebook runs correctly.
#    </font>
# +  <font color="red">
#     Save your file again.
#    </font>
# +  <font color="red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </font>
#
#    **lastname-firstname-labwork-xx.ipynb**
#
#    NB: Please note lowercase.

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (30 pts)](#a1) Acetyldehyde pyrolysis
#  - [1.1)](#a11)(10 pts) Reaction mechanism.
#  - [1.2)](#a12)(10 pts) Stoichiometric analysis.
#  - [1.3)](#a13)(10 pts) Reaction rate calculation.
# * [Assignment 2 (35 pts)](#a2) Propane pyrolysis.
#  - [2.1)](#a21)(10 pts) Reaction mechanism.
#  - [2.2)](#a22)(10 pts) Stoichiometric analysis.
#  - [2.3)](#a23)(15 pts) Reaction rate calculation.
# * [Assignment 3 (30 pts)](#a3) COVID-19 US death data.
#  - [3.1)](#a31)(10 pts) Import and plot data.
#  - [3.2)](#a32)(10 pts) LLSQ method with polynomial basis functions.
#  - [3.3)](#a33)(10 pts) Error analysis.
# * [Assignment 4 (5 pts)](#a4) Unclear points.
# ---

# %% [markdown]
# ## [<font color="blue">Assignment 1 (30 pts)</font>](#toa)<a id="a1"></a>

# %% [markdown]
# ### <font color="blue">[1.1)](#toa)(10 pts) Import the following reaction mechanism for acetaldehyde pyrolysis from the course repository: `data/acetaldehyde-pyrolysis-rxn.txt` and display the reactions.</font><a id="a11"></a>

# %%
'''1.1) Read reaction mechanism'''

# %% [markdown]
# ### <font color="blue">[1.2)](#toa)(10 pts) Print and plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is mass conservation satisfied? Explain.</font><a id="a12"></a>

# %%
'''1.2) Stoichimetric matrix data'''
# Out:
# matrix shape = (5, 9)

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ### <font color="blue">[1.3)](#toa)(10 pts) Given the species production rate density vector [mol/(s cc)] below, </font>
# <br>
# <font color="blue">
# $\gvec = \begin{pmatrix}
# -9.4979 \\ -3.2678 \\ 14.3472 \\ -0.9519 \\ -0.6297 \\ -11.0794 \\  3.8975 \\  1.48 \\   -2.2128
#  \end{pmatrix}
# $
# </font>
# in this order:
# CH3, CH3CHO, CH3CO, CH3I, CH4, CO, HI, I, I2
#
# ### <font color="blue"> compute and plot the reaction rate density vector (state units), explain step-by-step the solution of the problem, and explain in what sense is the reaction rate density vector a solution of the problem. Is the solution unique? Justify your answer? Explain the meaning of the sign of the reaction rates.
# </font><a id="a13"></a>

# %%
'''1.3) Code to calculate reaction rates'''
# Out:
# r [unit?] =  [  3.1647   3.2678 -11.0794  -0.9519  -0.6297]

# %%
'''1.3) Plot of reaction rates'''

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 2 (35 pts)</font>](#toa)<a id="a2"></a>

# %% [markdown]
# ### <font color="blue">[2.1)](#toa)(10 pts) Import the following reaction mechanism for propane pyrolysis from the course repository: `data/propane-rxn.txt` and display the reactions: </font><a id="a21"></a>

# %%
'''1.1) Read reaction mechanism'''

# %% [markdown]
# ### <font color="blue">[2.2)](#toa)(10 pts) Plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is mass conservation satisfied? Explain.</font><a id="a22"></a>

# %%
'''2.2) Stoichimetric matrix data'''
# Out:
# matrix shape = (8, 10)

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <font color="blue">[2.3)](#toa)(15 pts) Given the species production rate density vector [mol/(s cc)] below, </font><a id="a22"></a>
# <br>
# <font color="blue">
# $\gvec = \begin{pmatrix}
#  -4.7878 \\  9.6082  \\ 1.4312 \\ -9.2405 \\ -8.684  \\ 11.6729 \\ 20.4249 \\ -14.1733 \\  0.0738 \\ -9.6422
#  \end{pmatrix}
# $
# </font>
# in this order: C2H4, C2H5*, C2H6, C3H6, C3H7*, C3H8, CH3*, CH4, H*, H2
#
# ### <font color="blue"> compute and plot the reaction rate density vector (state units), explain step-by-step the solution of the problem, and explain in what sense is the reaction rate density vector a solution of the problem. Is the solution unique? Justify your answer? Explain the meaning of the sign of the reaction rates.
# </font><a id="a23"></a>

# %%
'''2.3) Code to calculate reaction rates'''
# Out:
# r [unit?] =  [ 4.3353 -9.6422 -2.8643 -6.7041  1.9163  1.4312 -7.7971 -6.3762]

# %%
'''2.3) Plot of reaction rates'''

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 3 (30 pts)</font>](#toa)<a id="a3"></a>

# %% [markdown]
# ### <font color="blue">[3.1)](#toa)(10 pts) Import the COVID-19 US death data below (you will need internet connection; data may change when you import data after 14Mar22) and reproduce the plot and printout below; dates spaced by 10 days.</font><a id="a31"></a>

# %%
'''3.1) Get data per state/territory in US'''

from chen_3170.help import get_covid_19_us_data

case_type = 'deaths'
(state_names, populations, dates, cases) = get_covid_19_us_data(type=case_type)

# %%
'''3.1) Sum cases'''
import numpy as np
population = np.sum(populations)
us_cases = np.sum(cases,axis=1)
# select data with non-zero cases only
(nz_cases_ids,) = np.where(us_cases>0)
us_cases = us_cases[nz_cases_ids]
us_dates = dates[nz_cases_ids]

# %%
'''3.1) Select data up until a given date'''

#date = None # get all the data available
date = '3/10/22' # set end date wanted
if date is not None:
    assert isinstance(date, str)
    (id,) = np.where(us_dates==date)
    assert id.size == 1
    us_dates = np.copy(us_dates[:id[0]+1])
    us_cases = np.copy(us_cases[:id[0]+1])

# %%
'''3.1) Plot data'''
# Out:
# Last 5 days; # of cumulative deaths until 3/10/22 = [958822. 960487. 961825. 963801. 965446.]
# Last 5 days; # of added deaths until 3/10/22 = [1665.0, 1338.0, 1976.0, 1645.0]

# %% [markdown]
# ### <font color="blue">[3.2)](#toa)(10 pts) Approximate the data using the linear least-squares method with polynomial basis functions using your algorithms. Find a polynomial degree that fits the data with mean local relative error less than 12%. Make a plot as below. Explain the method you used as best as you can.
# </font><a id="a32"></a>

# %%
'''3.2) Build/solve linear system'''

# %%
'''3.2) Plot polynomial fit'''

# %% [markdown]
# <font color="blue">**Explanation:** </font>

# %% [markdown]
# ### <font color="blue">[3.3)](#toa)(10 pts) Analyze the local relative error and explain. How would you improve this method to fit the data with a much lower error?</font><a id="a33"></a>

# %%
'''3.3) Local relative errors'''
# Out:
# Discard dates with small number of cases: use dates with > 1000 deaths
# Local Relative Error:
# mean [%] = 10.62
# std  [%] = 71.84
# max, min [%] = 1158.75, 0.00

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 4 (5 pts)</font>](#toa)<a id="a4"></a>

# %% [markdown]
# ### <font color="blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</font>
