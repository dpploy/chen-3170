# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Spring 2022 UMass Lowell; Prof. V. F. de Almeida **29Mar22**
#
# # Laboratory Work 06 (29Mar22) Solution
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
#   \newcommand{\Jmtrx}{\boldsymbol{\mathsf{J}}}
#   \newcommand{\Xmtrx}{\boldsymbol{\mathsf{X}}}
#   \newcommand{\Kmtrx}{\boldsymbol{\mathsf{K}}}
#   \newcommand{\abs}[1]{\left\lvert{#1}\right\rvert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\gradx}{\nabla\!_{\xvec}}
#   \DeclareMathOperator{\partialx}{\partial_\xvec}
#   \newcommand{\Kcal}{\mathcal{K}}
#   \newcommand{\Kcalvec}{\boldsymbol{\mathcal{K}}}
#   \newcommand{\epsvec}{\boldsymbol{\varepsilon}}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <font color="red">Guidance:</font>
#
# +  <font color="red">
#     Save your work frequently to a file locally to your computer.
#    </font>
# +  <font color="red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<font color="red">, to verify your notebook runs correctly.
#    </font>
# +  <font color="red">
#     Save your file again.
#    </font>
# +  <font color="red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </font>
#
#    **lastname-firstname-labwork-xx.ipynb**
#
#    NB: Please note lowercase.

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (45 pts)](#a1) Arbritrary single reaction
#  - [1.1)](#a11)(5 pts) Reaction mechanism.
#  - [1.2)](#a12)(5 pts) Stoichiometric analysis.
#  - [1.3)](#a13)(20 pts) Equilibrium calculation.
#  - [1.4)](#a14)(10 pts) Plot extent of reaction at equilibrium
#  - [1.5)](#a15)(5 pts) Summary.
# * [Assignment 2 (50 pts)](#a2) Propane pyrolysis.
#  - [2.1)](#a21)(5 pts) Reaction mechanism.
#  - [2.2)](#a22)(5 pts) Stoichiometric analysis.
#  - [2.3)](#a23)(25 pts) Equilibrium calculation.
#  - [2.4)](#a24)(10 pts) Plot extent of reactions at equilibrium.
#  - [2.5)](#a25)(5 pts) Summary.
# * [Assignment 3 (5 pts)](#a3) Unclear points.
# ---

# %% [markdown]
# ## [<font color="blue">Assignment 1 (45 pts)</font>](#toa)<a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue"> Find the equilibrium molar fraction of all species involved in the following arbitrary reaction:</span>
#
# <br>
# <span style="color:blue">
# \begin{equation*}
# \nu_A\,\text{A} + \nu_B\,\text{B} + \nu_C\,\text{C}
# \overset{K_x}{\longleftrightarrow}
# \nu_D\,\text{D} + \nu_E\,\text{E} + \nu_F\,\text{F}
# \end{equation*}
# </span>
#
# ### <span style="color:blue">where $K_x$ is the molar fraction based equilibrium constant. The following initial charge to the reactor vessel is:</span>
#
# Name                        | Parameter    | Value  | Name     | Parameter | Value |
# ----------------------------|--------------|--------|----------|-----------|-------|
# initial mole fraction of A  | $x_{A_0}$    | 0.4    | stoic. A | $\nu_A$   |  1.7  |
# initial mole fraction of B  | $x_{B_0}$    | 0.1    | stoic. B | $\nu_B$   |  2.1  |
# initial mole fraction of C  | $x_{C_0}$    | 0.01   | stoic. C | $\nu_C$   |  1.5  |
# initial mole fraction of D  | $x_{D_0}$    | 0.1    | stoic. D | $\nu_D$   |  3    |
# initial mole fraction of E  | $x_{E_0}$    | 0.3    | stoic. E | $\nu_E$   |  3.8  |
# initial mole fraction of F  | $x_{F_0}$    |residual| stoic. F | $\nu_F$   |  1.2  |
# mole equilibrium constant   | $K_\text{x}$ | 87.9   |     .    |    .      |  .    |

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(5 pts) Build the reaction mechanism and display the reaction.</span><a id="a11"></a>

# %%
'''1.1) Reaction mechanism'''

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(5 pts) Print and plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is the matrix full rank? What can you say about mass conservation? Explain.</span><a id="a12"></a>

# %%
'''1.2) Stoichimetric matrix data'''
# Out:
# r0 :  1.7 A + 2.1 B + 1.5 C <=> 3 D + 3.8 E + 1.2 F
# n_reactions = 1
# [('r0', 'K_x=87.9')]
# matrix shape = (1, 6)

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(20 pts) Using Newton's method and the course notes, compute (using your own algorithms) and report the equilibrium mole fractions for all species as follows (values are for your reference):</span><a id="a13"></a>
#
#      species name   molar fraction
#          x         3.828e-01 (38.28%)
#          x         3.185e-01 (31.85%)
#          x         1.169e-01 (11.69%)
#          x         9.593e-02 (9.59%)
#          x         8.532e-02 (8.53%)
#          x         5.441e-04 (0.05%)

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(10 pts) Plot the normalized extention of reaction root.</span><a id="a14"></a>

# %%
'''1.4) Plot equilibrium vector function'''

# %% [markdown]
# ### <span style="color:blue">[1.5)](#toa)(5 pts) Summary of key computational steps needed to solve the problem.</span><a id="a15"></a>

# %% [markdown]
# <font color="blue">**Explanation:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 2 (50 pts)</font>](#toa)<a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue"> Find the equilibrium molar fraction of all species involved in a model of the pyrolysis of propane in a closed reactor vessel: see file `data/propane-rxn.txt`, where $K_x$ is the reaction equilibrium constant based on molar fraction. At some point in time, the charge to the reactor vessel was given:
# </span>
#
# | Species | Empirical Formula | Mole Fraction | Value [%] |
# |-------------|-----------------|--------------|-------|
# |propylene     | C3H6 | $x_\text{C3H6}$ |  5   |
# |ethylene     | C2H4   | $x_\text{C2H4}$   | 1  |
# |methane | CH4      | $x_\text{CH4}$      | 10   |
# |hydrogen radical    | H*     | $x_\text{H*}$     | 0.5  |
# |ethane      | C2H6    | $x_\text{C2H6}$    | 0.5     |
# |methyl radical      | CH3*  | $x_\text{CH3*}$  | 1  |
# |ethyl radical         | C2H5*     | $x_\text{C2H5*}$     | 0.5      |
# |propane           | C3H8  | $x_\text{C3H8}$  |80     |
# |hydrogen| H2     | $x_\text{H2}$     | 0.5      |
# |propyl radical      | C3H7*     | $x_\text{C3H7*}$     | 1      |

# %%
'''Create as many cells as needed to organize the algorithms'''
# Out:
# 'Create as many cells as needed to organize the algorithms'

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(5 pts) Import the following reaction mechanism for propane pyrolysis from the course repository: `data/propane-rxn.txt` and display the reactions: </span><a id="a21"></a>

# %%
'''2.1) Read reaction mechanism'''
# Out:
# r0 :  C3H8         <-> CH3* + C2H5*
# r1 :  C3H8 + H*    <-> H2 + C3H7*
# r2 :  C3H7*        <-> C3H6 + H*
# r3 :  C2H5*        <-> C2H4 + H*
# r4 :  C3H7*        <-> C2H4 + CH3*
# r5 :  C2H5* + C3H8 <-> C2H6 + C3H7*
# r6 :  CH3* + C3H8  <-> CH4 + C3H7*
# r7 :  CH3* + C3H7* <-> C3H6 + CH4
# n_reactions = 8

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(5 pts) Plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is mass conservation satisfied? Explain.</span><a id="a22"></a>

# %%
'''2.2) Stoichimetric matrix data'''
# Out:
# r0 :  C3H8         <-> CH3* + C2H5*
# r1 :  C3H8 + H*    <-> H2 + C3H7*
# r2 :  C3H7*        <-> C3H6 + H*
# r3 :  C2H5*        <-> C2H4 + H*
# r4 :  C3H7*        <-> C2H4 + CH3*
# r5 :  C2H5* + C3H8 <-> C2H6 + C3H7*
# r6 :  CH3* + C3H8  <-> CH4 + C3H7*
# r7 :  CH3* + C3H7* <-> C3H6 + CH4
# n_reactions = 8
# [('r0', 'K_x=33.0'), ('r1', 'K_x=23.0'), ('r2', 'K_x=1.3'), ('r3', 'K_x=0.1'), ('r4', 'K_x=0.3'), ('r5', 'K_x=13.0'), ('r6', 'K_x=8.1'), ('r7', 'K_x=0.9')]
# matrix shape = (8, 10)

# %% [markdown]
# <font color="blue">**Explanation:** </font>

# %% [markdown]
# ### <span style="color:blue">[2.3)](#toa)(25 pts) Using Newton's method and the course notes, compute (using your own algorithms) and report the equilibrium mole fractions for all species as follows (values are for your reference):</span><a id="a23"></a>
#
#     formula      species name
#
#       xxxx          name     = 2.313e-01 (23.13%)
#       xxxx          name     = 2.043e-01 (20.43%)
#       xxxx          name     = 2.025e-01 (20.25%)
#       xxxx          name     = 1.113e-01 (11.13%)
#       xxxx          name     = 1.017e-01 (10.17%)
#       xxxx          name     = 5.292e-02 (5.29%)
#       xxxx          name     = 3.604e-02 (3.60%)
#       xxxx          name     = 3.163e-02 (3.16%)
#       xxxx          name     = 2.764e-02 (2.76%)
#       xxxx          name     = 6.888e-04 (0.07%)

# %% [markdown]
# ### <span style="color:blue">[2.4)](#toa)(10 pts) Plot all normalized extention of reaction roots.</span><a id="a24"></a>

# %%
'''2.4) Plot equilibrium vector function'''

n_pts = 100

plot_keq_function(ext_hat_vec_min, ext_hat_vec, n_pts, 
                  x_vec_0, keq_cte_vec, rxn_mech.stoic_mtrx, ext_hat_vec, hide=True)

# %% [markdown]
# ### <font color="blue">[2.5)](#toa)(5 pts) Provide a summary of key computational steps needed to solve the problem. Elaborate mathematically.</font><a id="a25"></a>

# %% [markdown]
# <font color="blue">**Key computation steps:**</font>

# %% [markdown]
# ## [<font color="blue">Assignment 3 (5 pts)</font>](#toa)<a id="a3"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>
