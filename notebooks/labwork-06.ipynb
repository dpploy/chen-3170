# %% [markdown]
# ChEn-3170: Computational Methods in Chemical Engineering Spring 2023 UMass Lowell; Prof. V. F. de Almeida **01Apr23**
#
# # Laboratory Work 06 (03Apr23)
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Cmtrx}{\boldsymbol{\mathsf{C}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Qmtrx}{\boldsymbol{\mathsf{Q}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\yvec}{\boldsymbol{\mathsf{y}}}
#   \newcommand{\zvec}{\boldsymbol{\mathsf{z}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\onevec}{\boldsymbol{\mathsf{1}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\abs}{abs}
#   \DeclareMathOperator{\sym}{sym}
# $

# %% [markdown]
# ### Name: `Your Name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |      Context       |  Points |
# |:----------------------------|:-------:|
# | Precision of the answer     |  80%    |
# | Answer Markdown readability |  10%    |
# | Code readability            |  10%    |

# %% [markdown]
# ### <font color="red">Guidance:</font>
#
# +  <font color="red">
#     Save your work frequently to a file locally to your computer.
#    </font>
# +  <font color="red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<font color="red">, to verify your notebook runs correctly.
#    </font>
# +  <font color="red">
#     Save your file again.
#    </font>
# +  <font color="red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </font>
#
#    **lastname-firstname-labwork-xx.ipynb**
#
#    NB: Please note lowercase.

# %% [markdown]
# ---
# ### Table of Assignments<a id="toa"></a>
# * [Assignment 1 (45 pts)](#a1) Arbritrary single reaction
#  - [1.1)](#a11)(5 pts) Reaction mechanism.
#  - [1.2)](#a12)(5 pts) Stoichiometric analysis.
#  - [1.3)](#a13)(20 pts) Equilibrium calculation.
#  - [1.4)](#a14)(10 pts) Plot extent of reaction at equilibrium
#  - [1.5)](#a15)(5 pts) Summary.
# * [Assignment 2 (50 pts)](#a2) Pyrolysis of ethyl nitrite in a closed reactor vessel.
#  - [2.1)](#a21)(5 pts) Rank of the stoichiometric matrix.
#  - [2.2)](#a22)(25 pts) Compute and report the equilibrium mole fractions in the reactor.
#  - [2.3)](#a23)(10 pts) Plot all normalized extent of reaction roots.
#  - [2.4)](#a24)(10 pts) Summary of key computational steps.
# * [Assignment 3 (5 pts)](#a3) Unclear points.
# ---

# %% [markdown]
# ## [<font color="blue">Assignment 1 (45 pts)</font>](#toa)<a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue"> Find the equilibrium molar fraction of all species involved in the following arbitrary reaction:</span>
#
# <br>
# <span style="color:blue">
# \begin{equation*}
# \nu_A\,\text{A} + \nu_B\,\text{B} + \nu_C\,\text{C}
# \overset{K_x}{\longleftrightarrow}
# \nu_D\,\text{D} + \nu_E\,\text{E} + \nu_F\,\text{F}
# \end{equation*}
# </span>
#
# ### <span style="color:blue">where $K_x$ is the molar-fraction-based equilibrium constant. The following initial charge to the reactor vessel is:</span>
#
# Name                        | Parameter    | Value  | Name     | Parameter | Value |
# ----------------------------|--------------|--------|----------|-----------|-------|
# initial mole fraction of A  | $x_{A_0}$    | 0.32    | stoic. A | $\nu_A$   |  1.7  |
# initial mole fraction of B  | $x_{B_0}$    | 0.23    | stoic. B | $\nu_B$   |  2.1  |
# initial mole fraction of C  | $x_{C_0}$    | 0.14   | stoic. C | $\nu_C$   |  1.5  |
# initial mole fraction of D  | $x_{D_0}$    | 0.12    | stoic. D | $\nu_D$   |  3    |
# initial mole fraction of E  | $x_{E_0}$    | 0.10    | stoic. E | $\nu_E$   |  3.8  |
# initial mole fraction of F  | $x_{F_0}$    |residual| stoic. F | $\nu_F$   |  1.2  |
# mole equilibrium constant   | $K_\text{x}$ | 87.9   |    -    |   -    | -   |

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(5 pts) Build the reaction mechanism and display the reaction.</span><a id="a11"></a>

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(5 pts) Print and plot the stoichiometric matrix, print the shape, list of species, and compute the rank of the matrix (using your own algorithm). Is the matrix full rank? What can you say about mass conservation? Explain.</span><a id="a12"></a>

# %%
'''Code'''
# Out:
# matrix shape = (1, 6)

# %% [markdown]
# <span style="color:blue">**Explanation:**</span>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(20 pts) Using Newton's method and the course notes, compute (using your own algorithms) and report the equilibrium mole fractions for all species as follows (values are for your reference):</span><a id="a13"></a>
#
#      species name   molar fraction
#          x         3.218e-01 (32.18%)
#          x         2.881e-01 (28.81%)
#          x         1.589e-01 (15.89%)
#          x         1.501e-01 (15.01%)
#          x         5.904e-02 (5.90%)
#          x         2.201e-02 (2.20%)

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(10 pts) Plot the normalized extention of reaction root.</span><a id="a14"></a>

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[1.5)](#toa)(5 pts) Summary of key computational steps needed to solve the problem.</span><a id="a15"></a>

# %% [markdown]
# <span style="color:blue">**Explanation:**
# </span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (50 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue"> Find the equilibrium molar fraction for a model of the pyrolysis of ethyl nitrite in a closed reactor vessel: see file `data/ethyl-nitrite-rxn.txt`:
# </span>
#
#  Pyrolysis mechanism            |         $K_x$        |
# --------------------------------|----------------------|
# C2H5ONO      <=> C2H5O   + NO   | 5.02e+00        |
# C2H5O        <=> CH3     + CH2O | 3.23e+00        |
# C2H5O + NO   <=> CH3CHO  + HNO  | 2.12e+00        |
# C2H5O + HNO  <=> C2H5OH  + NO   | 3.65e+00        |
# 2 NOH        <=> N2O     + H2O  | 1.45e-01   |
# CH3 + NO     <=> CH3NO          | 1.67e+00     |
# CH3NO        <=> CH2=NOH        | 1.09e-00   |
# CH2=NOH      <=> HCN     + H2O  | 1.14e-01   |
#
# ### <span style="color:blue"> where $K_x$ the reaction equilibrium constant based on molar fraction. At some point in time, the charge to the reactor vessel was given:
# </span>
#
# | Species | Empirical Formula | Mole Fraction | Value [%] |
# |-------------|-----------------|--------------|-------|
# |ethyl nitrite     | C2H5ONO | $x_\text{C2H5ONO}$ |  73   |
# |hydroxyethyl      | C2H5O   | $x_\text{C2H5O}$   | 1  |
# |nitrogen monoxide | NO      | $x_\text{NO}$      | 3   |
# |methyl radical    | CH3     | $x_\text{CH3}$     | 0.5  |
# |formaldehyde      | CH2O    | $x_\text{CH2O}$    | 5.5     |
# |acetaldehyde      | CH3CHO  | $x_\text{CH3CHO}$  | 2  |
# |nitroxyl          | HNO     | $x_\text{HNO}$     | 0.5      |
# |ethanol           | C2H5OH  | $x_\text{C2H5OH}$  | 1      |
# |nitrogen hydroxide| NOH     | $x_\text{NOH}$     | 5      |
# |nitric oxide      | N2O     | $x_\text{N2O}$     | 1.5      |
# |water             | H2O     | $x_\text{H2O}$     | 1   |
# |formamide         | CH3NO   | $x_\text{CH3NO}$   | 3     |
# |formaldoxime      | CH2=NOH | $x_\text{CH2=NOH}$ | 0.5   |
# |hydrogen cyanide  | HCN     | $x_\text{HCN}$     | 2.5      |

# %%
'''Create as many cells as needed to organize the algorithms'''
# Out:
# 'Create as many cells as needed to organize the algorithms'

# %%
'''Code'''
# Out:
# matrix shape = (8, 14)

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(5 pts) What is the rank of the stoichiometric matrix. Is it full rank? Or rank deficient? Justify your answer.</span><a id="a21"></a>

# %%
'''Code'''

# %% [markdown]
# <span style="color:blue">**Explanation:** </span>

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(25 pts) Compute and report the equilibrium mole fractions for all species as follows (values are for your reference):</span><a id="a22"></a>
#
#       formula      species name
#         xxxx         name         = 2.837e-01 (28.37%)
#         xxxx         name         = 1.716e-01 (17.16%)
#         xxxx         name         = 1.335e-01 (13.35%)
#         xxxx         name         = 7.496e-02 (7.50%)
#         xxxx         name         = 7.416e-02 (7.42%)
#         xxxx         name         = 6.339e-02 (6.34%)
#         xxxx         name         = 5.749e-02 (5.75%)
#         xxxx         name         = 4.168e-02 (4.17%)
#         xxxx         name         = 3.824e-02 (3.82%)
#         xxxx         name         = 3.245e-02 (3.25%)
#         xxxx         name         = 1.434e-02 (1.43%)
#         xxxx         name         = 1.172e-02 (1.17%)
#         xxxx         name         = 2.409e-03 (0.24%)
#         xxxx         name         = 4.007e-04 (0.04%)

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[2.3)](#toa)(10 pts) Plot all normalized extention of reaction roots:</span><a id="a23"></a>

# %%
'''Code'''

# %% [markdown]
# ### <span style="color:blue">[2.4)](#toa)(10 pts) Summary of key computational steps needed to solve the problem.</span><a id="a24"></a>

# %% [markdown]
# **Key computation steps:**

# %% [markdown]
# ## [<font color="blue">Assignment 3 (5 pts)</font>](#toa)<a id="a3"></a>

# %% [markdown]
# ### <font color="blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</font>

# %% [markdown]
# **Description and troubleshooting:**
